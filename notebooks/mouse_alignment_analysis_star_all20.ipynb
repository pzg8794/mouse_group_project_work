# %% [markdown]
# # Mouse Alignment Analysis — STAR All 20 (`SRP618841`)
#
# This is the team-share version of the `mouse_new` alignment walkthrough. It summarizes the shared `SRP618841` STAR run and focuses on three practical questions:
#
# 1. Are the alignment metrics strong enough to proceed to DE?
# 2. Do the remaining GC-WARN samples look different at the alignment stage?
# 3. Is there any major platform split left to worry about in this dataset?

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path('..').resolve()
DATA = ROOT / 'data' / 'alignment_analysis_star_all20'
TABLES = DATA / 'tables'
FIGS = DATA / 'figures'

# %% [markdown]
# ## Shared alignment inputs
#
# These artifacts were exported from the shared `SRP618841` alignment run on `sequoia` and copied into this repo so the team can inspect them without using the full private working tree.

# %%
summary = pd.read_csv(TABLES / 'mouse_alignment_sample_summary.tsv', sep='	')
summary.head()
# Out:
#            srr  input_reads  avg_input_read_length  unique_reads  unique_pct  \
# 0  SRR35329977     89957186                  266.0      84106984       93.50
# 1  SRR35329978     61342187                  263.0      57189550       93.23
# 2  SRR35329979     89605541                  267.0      83458675       93.14
# 3  SRR35329980     58788435                  266.0      55024578       93.60
# 4  SRR35329981     75914744                  263.0      70781745       93.24
#
#    avg_mapped_length  mismatch_rate_pct  multi_reads  multi_pct  \
# 0             263.84               0.19      4521532       5.03
# 1             261.02               0.19      3182634       5.19
# 2             264.33               0.20      4352052       4.86
# 3             263.95               0.19      2858608       4.86
# 4             260.92               0.19      3951285       5.20
#
#    too_many_loci_reads  ...                 sample_description  replicate  \
# 0               167906  ...  Library name: H64ffcre1dpiDRGipsi        NaN
# 1               112869  ...     Library name: H65ff1dpiDRGipsi        NaN
# 2               154169  ...   Library name: H96ff1dpiDRGcontra        NaN
# 3               101316  ...   Library name: H97ff1dpiDRGcontra        NaN
# 4               133084  ...   Library name: H65ff1dpiDRGcontra        NaN
#
#                                        group_label  gc_warn_mates  gc_status  \
# 0  Replicate H64, CRE genotype, Ipsilateral tissue              1       WARN
# 1     Replicate H65,  Wildtype, Ipsilateral tissue              1       WARN
# 2   Replicate H96,  Wildtype, Contralateral tissue              2       WARN
# 3   Replicate H97,  Wildtype, Contralateral tissue              2       WARN
# 4   Replicate H65,  Wildtype, Contralateral tissue              1       WARN
#
#    N_unmapped_pct_of_input  N_multimapping_pct_of_input  \
# 0                 1.477824                     5.026316
# 1                 1.581960                     5.188328
# 2                 2.003798                     4.856901
# 3                 1.540560                     4.862535
# 4                 1.557306                     5.204898
#
#    N_noFeature_pct_of_input N_ambiguous_pct_of_input source_group
# 0                  3.819048                 1.759548         Ipsi
# 1                  3.740375                 1.785500         Ipsi
# 2                  3.944528                 1.766326       Contra
# 3                  3.934357                 1.709299       Contra
# 4                  3.822496                 1.746707       Contra
#
# [5 rows x 43 columns]

# %% [markdown]
# The sample summary is the main alignment handoff table. It combines STAR metrics, run metadata, and the GC status that was carried forward from the trimmed-QC stage.

# %%
summary[['unique_pct', 'input_reads']].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 summary[['unique_mapped_percent', 'input_reads']].describe()
#
# File ~/DataScience/Semester5/BIOL550/biol550_env/lib/python3.13/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~/DataScience/Semester5/BIOL550/biol550_env/lib/python3.13/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/DataScience/Semester5/BIOL550/biol550_env/lib/python3.13/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['unique_mapped_percent'] not in index"

# %% [markdown]
# ## Compact alignment summaries
#
# These small summary tables help us see whether platform or GC status is dominating the alignment layer.

# %%
by_platform = pd.read_csv(TABLES / 'alignment_metric_by_platform_median.tsv', sep='	')
by_gc = pd.read_csv(TABLES / 'alignment_metric_by_gc_status_median.tsv', sep='	')
display(by_platform)
display(by_gc)

# %% [markdown]
# ## Figures
#
# These are the main alignment visuals for the team walkthrough.

# %%
display(Image(filename=str(FIGS / 'unique_mapping_by_sample.png'), width=1200))
display(Image(filename=str(FIGS / 'unique_mapping_by_platform.png'), width=900))
display(Image(filename=str(FIGS / 'unique_mapping_by_gc_status.png'), width=900))

# %%
display(Image(filename=str(FIGS / 'input_reads_by_platform.png'), width=900))
display(Image(filename=str(FIGS / 'assignment_burden_by_platform.png'), width=900))

# %% [markdown]
# ## Main takeaways
#
# - The `SRP618841` alignment layer is strong enough to proceed to DE.
# - This dataset is much cleaner structurally than the older mixed-platform mouse set because all retained samples come from `NovaSeq X`.
# - GC warnings still exist, but they do not create a separate failed alignment branch that would block downstream analysis.
